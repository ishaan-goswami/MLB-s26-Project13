# %% [markdown]
# # Report Analysis Template
#
# Use this notebook after running the pipeline scripts. It is intended for figures, summary tables, and case-study inspection for the final report.

# %%
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ROOT = Path('..').resolve()
EVAL_DIR = ROOT / 'artifacts' / 'eval'
SEARCH_DIR = ROOT / 'artifacts' / 'search'
PROCESSED_DIR = ROOT / 'data' / 'processed'

sns.set_theme(style='whitegrid')

# %% [markdown]
# ## Load Evaluation Summaries

# %%
raw_summary = pd.read_csv(EVAL_DIR / 'esm2_650m_raw_summary.csv')
raw_summary

# %% [markdown]
# ## Example Bar Plot for GO Jaccard

# %%
ax = sns.barplot(data=raw_summary, x='aspect', y='mean_go_jaccard')
ax.set_title('Mean GO Jaccard by Ontology')
plt.tight_layout()

# %% [markdown]
# ## Inspect Failure Cases

# %%
detailed = pd.read_csv(EVAL_DIR / 'esm2_650m_raw_detailed.csv')
detailed.sort_values('go_jaccard').head(20)
